# %% [markdown]
# # Beginner's Guide to Clustering with K-Means

# %% [markdown]
# Clustering is a type of unsupervised machine learning where the goal is to group similar data points together. It groups data into 'K' number of clusters. The number of clusters is user-defined(ex-if K=5, there will be five clusters) and the algorithm iteratively assigns each data point to one of the 'k' clusters based on the features that are provided.

# %% [markdown]
# # Behind the K-means

# %% [markdown]
# It uses the Euclidean distance formula to measure the distance between each data point and each cluster point.
# It then assigns each data point to the cluster who's center is nearest to the data point.
# Then finally to find the center of the newly formed cluster, we take the mean of the data point obtained in that cluster.

# %% [markdown]
# # Implementation using Python-:

# %% [markdown]
# Now enough for the theory part, let's jump right into the code for better understanding (:
# But before that make sure you have numpy, pandas, sklearn and matplotlib libraries.

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %% [markdown]
# # LOADING THE DATASET
# For this demonstration we will be using a famous dataset called the iris(which is about flowers)

# %%
iris = load_iris()
X = iris.data

# %%
#Creating and fitting the model-
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

# %%
#Assigning the clusters and plotting them
labels = kmeans.labels_

plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.show()

# %% [markdown]
# The above plot shows the first two features of the iris dataset that is the sepal lenght and the sepal widht. Each point is the iris flower.
# The colors of the points represent the clusters that the K-Means algorithm has assigned the flowers to. Since we set n_clusters=3, there are three different colors. The algorithm tries to group the flowers based on the similarity of their features.

# %% [markdown]
# And Congratulations you just learned about K Means clustering algorithm
# There are some advanced techniques in this like the elbow method which we can use for finding the optimal number of clusters but this is enough for a good beginner friendly tutorial :)
